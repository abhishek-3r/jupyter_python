# %%
import pandas as pd

# %%
#Create a series of car type
cars = pd.Series(['BMW','Chevrolet','Honda'])
cars
# Out:
# 0          BMW
# 1    Chevrolet
# 2        Honda
# dtype: object

# %%
#Create a Series of Colors
colors = pd.Series(['Red','Yellow','Blue','Orange'])
colors
# Out:
# 0       Red
# 1    Yellow
# 2      Blue
# 3    Orange
# dtype: object

# %%
car_data = pd.DataFrame({'Car Make':cars , 'color':colors })
car_data
# Out:
#     Car Make   color
# 0        BMW     Red
# 1  Chevrolet  Yellow
# 2      Honda    Blue
# 3        NaN  Orange

# %%
car_data.to_csv('exported car data.csv', index = False)

# %%
#import new data file in pandas
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df_missing = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv")

# %%
df_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# ## Discribe data with pandas

# %%
# Attribute - Give information about the data
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Funtion - to perform step or further step
# car_sales.to_csv("exported-car-sales.csv",index=False)

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.median()
# Out:
# Odometer (KM)    57369.0
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([300,430,900])
car_prices.mean()
# Out:
# 543.3333333333334

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.shape
# Out:
# (10, 5)

# %% [markdown]
# ## Viewing and Selecting data in pandas

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# loc & iloc

# %%
#loc refers to index
animals = pd.Series(['cat','dog','cow','elephant','Pandas'], index = [0,5,8,5,16])
animals
# Out:
# 0          cat
# 5          dog
# 8          cow
# 5     elephant
# 16      Pandas
# dtype: object

# %%
animals.loc[5]
# Out:
# 5         dog
# 5    elephant
# dtype: object

# %%
#iloc -iloc refers to postion
animals.iloc[4]
# Out:
# 'Pandas'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.iloc[9]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)        31600
# Doors                    4
# Price            $9,700.00
# Name: 9, dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0    cat
# 5    dog
# 8    cow
# dtype: object

# %%
car_sales.loc[2:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales['Odometer (KM)'] > 50000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Make'] == 'Toyota'].mean()
# Out:
# Odometer (KM)    85451.25
# Doors                3.75
# dtype: float64

# %%
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Groupby
car_sales.groupby(car_sales['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.plot()

# %%
car_sales['Doors'].plot()

# %%
car_sales['Odometer (KM)'].plot()

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027BB279B148>,
# ...
#       dtype=object)

# %%
car_sales['Odometer (KM)'].hist()

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales['Price']=car_sales['Price'].replace('[\$,]', '', regex=True).astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['Price'].plot()

# %%
car_sales = car_sales.rename(columns = {'Price' : '$Price'})

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   $Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['$Price'].plot()

# %% [markdown]
# # Manipulate data in pandas

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   $Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['Make'] = car_sales['Make'].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   $Price
# 0  TOYOTA  White         150043      4   4000.0
# 1   HONDA    Red          87899      4   5000.0
# 2  TOYOTA   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  NISSAN  White         213095      4   3500.0
# 5  TOYOTA  Green          99213      4   4500.0
# 6   HONDA   Blue          45698      4   7500.0
# 7   HONDA   Blue          54738      4   7000.0
# 8  TOYOTA  White          60000      4   6250.0
# 9  NISSAN  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv(r"C:\Users\abhis\Downloads\car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_drpped = car_sales_missing_dropped['Price'].replace('[\$,]', '', regex=True).astype(float)

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   $Price
# 0  TOYOTA  White         150043      4   4000.0
# 1   HONDA    Red          87899      4   5000.0
# 2  TOYOTA   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  NISSAN  White         213095      4   3500.0
# 5  TOYOTA  Green          99213      4   4500.0
# 6   HONDA   Blue          45698      4   7500.0
# 7   HONDA   Blue          54738      4   7000.0
# 8  TOYOTA  White          60000      4   6250.0
# 9  NISSAN  White          31600      4   9700.0

# %%
seat_column = pd.Series([5,5,5,5,5])

# %%
car_sales['Seats'] = seat_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   $Price  Seats
# 0  TOYOTA  White         150043      4   4000.0    5.0
# 1   HONDA    Red          87899      4   5000.0    5.0
# 2  TOYOTA   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  NISSAN  White         213095      4   3500.0    5.0
# 5  TOYOTA  Green          99213      4   4500.0    NaN
# 6   HONDA   Blue          45698      4   7500.0    NaN
# 7   HONDA   Blue          54738      4   7000.0    NaN
# 8  TOYOTA  White          60000      4   6250.0    NaN
# 9  NISSAN  White          31600      4   9700.0    NaN

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["seats"] = pd.Series([5,5,5,5,5])

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["seats"].fillna(car_sales["seats"].mean() ,inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
car_sales['Price']=car_sales['Price'].replace('[\$,]', '', regex=True).astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
car_sales.rename(columns = {'Price' : '$Price'})
# Out:
#      Make Colour  Odometer (KM)  Doors   $Price  seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
#creating new column - fuel_economyof python List

car_sales['Fuel per 100km'] = [4.5,5.6,5,7,5.6,8.6,11.2,9,3.6,10.6]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  \
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0
#
#    Fuel economy per 100km  Fuel per 100km
# 0                     4.5             4.5
# 1                     5.6             5.6
# 2                     5.0             5.0
# 3                     7.0             7.0
# 4                     5.6             5.6
# 5                     8.6             8.6
# 6                    11.2            11.2
# ...

# %%
del car_sales['Fuel economy per 100km']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km
# 0  Toyota  White         150043      4   4000.0    5.0             4.5
# 1   Honda    Red          87899      4   5000.0    5.0             5.6
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             7.0
# 4  Nissan  White         213095      4   3500.0    5.0             5.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.6
# 6   Honda   Blue          45698      4   7500.0    5.0            11.2
# 7   Honda   Blue          54738      4   7000.0    5.0             9.0
# 8  Toyota  White          60000      4   6250.0    5.0             3.6
# 9  Nissan  White          31600      4   9700.0    5.0            10.6

# %%
car_sales['Total Fuel used (L)'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100km']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 0  Toyota  White         150043      4   4000.0    5.0             4.5
# 1   Honda    Red          87899      4   5000.0    5.0             5.6
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             7.0
# 4  Nissan  White         213095      4   3500.0    5.0             5.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.6
# 6   Honda   Blue          45698      4   7500.0    5.0            11.2
# 7   Honda   Blue          54738      4   7000.0    5.0             9.0
# 8  Toyota  White          60000      4   6250.0    5.0             3.6
# 9  Nissan  White          31600      4   9700.0    5.0            10.6
#
#    Total Fuel used (L)
# 0             6751.935
# 1             4922.344
# 2             1627.450
# 3              782.530
# 4            11933.320
# 5             8532.318
# ...

# %%
car_sales['Total Fuel used (L)'] = car_sales['Odometer (KM)']/(100/car_sales['Fuel per 100km'])

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 0  Toyota  White         150043      4   4000.0    5.0             4.5
# 1   Honda    Red          87899      4   5000.0    5.0             5.6
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             7.0
# 4  Nissan  White         213095      4   3500.0    5.0             5.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.6
# 6   Honda   Blue          45698      4   7500.0    5.0            11.2
# 7   Honda   Blue          54738      4   7000.0    5.0             9.0
# 8  Toyota  White          60000      4   6250.0    5.0             3.6
# 9  Nissan  White          31600      4   9700.0    5.0            10.6
#
#    Total Fuel used (L)
# 0             6751.935
# 1             4922.344
# 2             1627.450
# 3              782.530
# 4            11933.320
# 5             8532.318
# ...

# %%
car_sales['Number of wheels'] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 0  Toyota  White         150043      4   4000.0    5.0             4.5
# 1   Honda    Red          87899      4   5000.0    5.0             5.6
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             7.0
# 4  Nissan  White         213095      4   3500.0    5.0             5.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.6
# 6   Honda   Blue          45698      4   7500.0    5.0            11.2
# 7   Honda   Blue          54738      4   7000.0    5.0             9.0
# 8  Toyota  White          60000      4   6250.0    5.0             3.6
# 9  Nissan  White          31600      4   9700.0    5.0            10.6
#
#    Total Fuel used (L)  Number of wheels
# 0             6751.935                 4
# 1             4922.344                 4
# 2             1627.450                 4
# ...

# %%
car_sales['Passed road safety'] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 7   Honda   Blue          54738      4   7000.0    5.0             9.0
# 6   Honda   Blue          45698      4   7500.0    5.0            11.2
# 1   Honda    Red          87899      4   5000.0    5.0             5.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.6
# 3     BMW  Black          11179      5  22000.0    5.0             7.0
# 0  Toyota  White         150043      4   4000.0    5.0             4.5
# 9  Nissan  White          31600      4   9700.0    5.0            10.6
# 4  Nissan  White         213095      4   3500.0    5.0             5.6
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 8  Toyota  White          60000      4   6250.0    5.0             3.6
#
#    Total Fuel used (L)  Number of wheels  Passed road safety
# 7             4926.420                 4                True
# 6             5118.176                 4                True
# ...

# %%
#For future machine learning sampling

car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 5  Toyota  Green          99213      4   4500.0    5.0             8.6
# 0  Toyota  White         150043      4   4000.0    5.0             4.5
# 1   Honda    Red          87899      4   5000.0    5.0             5.6
# 3     BMW  Black          11179      5  22000.0    5.0             7.0
# 8  Toyota  White          60000      4   6250.0    5.0             3.6
# 4  Nissan  White         213095      4   3500.0    5.0             5.6
# 9  Nissan  White          31600      4   9700.0    5.0            10.6
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 6   Honda   Blue          45698      4   7500.0    5.0            11.2
# 7   Honda   Blue          54738      4   7000.0    5.0             9.0
#
#    Total Fuel used (L)  Number of wheels  Passed road safety
# 5             8532.318                 4                True
# 0             6751.935                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                  float64
# seats                  float64
# Fuel per 100km         float64
# Total Fuel used (L)    float64
# Number of wheels         int64
# Passed road safety        bool
# dtype: object

# %%
car_sales =car_sales.sample(frac=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 7   Honda   Blue          54738      4   7000.0    5.0             9.0
# 6   Honda   Blue          45698      4   7500.0    5.0            11.2
# 1   Honda    Red          87899      4   5000.0    5.0             5.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.6
# 3     BMW  Black          11179      5  22000.0    5.0             7.0
# 0  Toyota  White         150043      4   4000.0    5.0             4.5
# 9  Nissan  White          31600      4   9700.0    5.0            10.6
# 4  Nissan  White         213095      4   3500.0    5.0             5.6
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 8  Toyota  White          60000      4   6250.0    5.0             3.6
#
#    Total Fuel used (L)  Number of wheels  Passed road safety
# 7             4926.420                 4                True
# 6             5118.176                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 7   Honda   Blue          54738      4   7000.0    5.0             9.0
# 6   Honda   Blue          45698      4   7500.0    5.0            11.2
# 1   Honda    Red          87899      4   5000.0    5.0             5.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.6
# 3     BMW  Black          11179      5  22000.0    5.0             7.0
# 0  Toyota  White         150043      4   4000.0    5.0             4.5
# 9  Nissan  White          31600      4   9700.0    5.0            10.6
# 4  Nissan  White         213095      4   3500.0    5.0             5.6
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 8  Toyota  White          60000      4   6250.0    5.0             3.6
#
#    Total Fuel used (L)  Number of wheels  Passed road safety
# 7             4926.420                 4                True
# 6             5118.176                 4                True
# ...

# %%
car_sales.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  seats  Fuel per 100km  \
# 8  Toyota  White          60000      4  6250.0    5.0             3.6
# 4  Nissan  White         213095      4  3500.0    5.0             5.6
#
#    Total Fuel used (L)  Number of wheels  Passed road safety
# 8              2160.00                 4                True
# 4             11933.32                 4                True

# %%
car_sales.reset_index(drop=True,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 0   Honda   Blue          54738      4   7000.0    5.0             9.0
# 1   Honda   Blue          45698      4   7500.0    5.0            11.2
# 2   Honda    Red          87899      4   5000.0    5.0             5.6
# 3  Toyota  Green          99213      4   4500.0    5.0             8.6
# 4     BMW  Black          11179      5  22000.0    5.0             7.0
# 5  Toyota  White         150043      4   4000.0    5.0             4.5
# 6  Nissan  White          31600      4   9700.0    5.0            10.6
# 7  Nissan  White         213095      4   3500.0    5.0             5.6
# 8  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 9  Toyota  White          60000      4   6250.0    5.0             3.6
#
#    Total Fuel used (L)  Number of wheels  Passed road safety
# 0             4926.420                 4                True
# 1             5118.176                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales['Odometer (KM)']/1.6

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 0   Honda   Blue      34211.250      4   7000.0    5.0             9.0
# 1   Honda   Blue      28561.250      4   7500.0    5.0            11.2
# 2   Honda    Red      54936.875      4   5000.0    5.0             5.6
# 3  Toyota  Green      62008.125      4   4500.0    5.0             8.6
# 4     BMW  Black       6986.875      5  22000.0    5.0             7.0
# 5  Toyota  White      93776.875      4   4000.0    5.0             4.5
# 6  Nissan  White      19750.000      4   9700.0    5.0            10.6
# 7  Nissan  White     133184.375      4   3500.0    5.0             5.6
# 8  Toyota   Blue      20343.125      3   7000.0    5.0             5.0
# 9  Toyota  White      37500.000      4   6250.0    5.0             3.6
#
#    Total Fuel used (L)  Number of wheels  Passed road safety
# 0             4926.420                 4                True
# 1             5118.176                 4                True
# ...

# %%
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x: x*1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Fuel per 100km  \
# 0   Honda   Blue        54738.0      4   7000.0    5.0             9.0
# 1   Honda   Blue        45698.0      4   7500.0    5.0            11.2
# 2   Honda    Red        87899.0      4   5000.0    5.0             5.6
# 3  Toyota  Green        99213.0      4   4500.0    5.0             8.6
# 4     BMW  Black        11179.0      5  22000.0    5.0             7.0
# 5  Toyota  White       150043.0      4   4000.0    5.0             4.5
# 6  Nissan  White        31600.0      4   9700.0    5.0            10.6
# 7  Nissan  White       213095.0      4   3500.0    5.0             5.6
# 8  Toyota   Blue        32549.0      3   7000.0    5.0             5.0
# 9  Toyota  White        60000.0      4   6250.0    5.0             3.6
#
#    Total Fuel used (L)  Number of wheels  Passed road safety
# 0             4926.420                 4                True
# 1             5118.176                 4                True
# ...
